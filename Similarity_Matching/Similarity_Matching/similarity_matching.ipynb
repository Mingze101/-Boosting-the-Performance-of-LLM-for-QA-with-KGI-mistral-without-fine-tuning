# %% [markdown]
# # Similarity Matching
# This file requires uploading two basic files: "extracted_entity_list.xlsx" and "extracted_relation_list.xlsx". The other files are process files and do not need to be uploaded. It is currently the most comprehensive version.

# %% [markdown]
# ## Find N Most Similarest Entitie

# %% [markdown]
# ### Find Most 5 Similarest Entities with BERT
# Our statistical results for similarity matching show that extracting the 5 most similar entities can cover the most exemplary question.
#
# I tried to use BERT and SpaCy models to perform similarity matching on entities. Finally, I found that bert-base-uncased can more efficiently find the most relevant entities for most problems in the first five, while other models cannot. There has been a significant improvement. For example, spacy's en_core_web_lg similarity results are much irrelevant to given entities.

# %%
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from scipy.spatial.distance import cosine
import re

# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

def bert_encode(text):
    # Tokenize and encode the text
    encoded_input = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    # Get the model output (last hidden state)
    with torch.no_grad():
        output = model(**encoded_input)
    # Use the mean of the last layer's features as the text embedding, ensure it's 1-D
    embedding = output.last_hidden_state.mean(dim=1).squeeze()
    return embedding

def compute_similarity(text1, text2):
    # Encode the texts
    embedding1 = bert_encode(text1)
    embedding2 = bert_encode(text2)
    # Ensure embeddings are numpy 1-D arrays for cosine similarity calculation
    embedding1_np = embedding1.cpu().numpy() if embedding1.is_cuda else embedding1.numpy()
    embedding2_np = embedding2.cpu().numpy() if embedding2.is_cuda else embedding2.numpy()
    # Compute cosine similarity
    return 1 - cosine(embedding1_np, embedding2_np)


def extract_abbreviation(text):
    if isinstance(text, str):
        match = re.search(r'\(([^)]+)\)', text)
        return match.group(1) if match else text
    else:
        return text

def find_most_similar_entities(df, entity_column):
    # Read data from an Excel file
    df_entity = pd.read_excel('../Entity_Relation_Extraction/extracted_entity_list .xlsx')
    df_entity['entity_abb'] = df_entity['entity_label'].apply(extract_abbreviation)
    df_entity['entity_lowercase'] = df_entity['entity_abb'].str.lower()

    def process_entity(question_entity):
        similarity_scores = {}
        threshold = 0.5  # You may need to adjust this based on BERT's behavior

        for index, row in df_entity.iterrows():
            if pd.isna(row['entity_lowercase']):
                continue

            similarity = compute_similarity(question_entity.lower(), row['entity_lowercase'])
            if similarity > threshold:
                similarity_scores[index] = similarity

        top_5_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:5]

        if top_5_similarities:
            similar_entities = [df_entity.at[index, 'entity_label'] for index, _ in top_5_similarities]
            entity_uris = [df_entity.at[index, 'entity_uri'] for index, _ in top_5_similarities]
            return similar_entities, entity_uris
        else:
            return None, None

    def process_entity_list(entity_list):
        similar_entities_list = []
        entity_uris_list = []

        for entity in entity_list.split(','):
            entity = entity.strip()
            if entity:
                similar_entities, entity_uris = process_entity(entity)
                if similar_entities and entity_uris:
                    similar_entities_list.extend(similar_entities)
                    entity_uris_list.extend(entity_uris)

        if similar_entities_list:
            return similar_entities_list, entity_uris_list
        else:
            return None, None

    results = df[entity_column].apply(lambda x: process_entity(x) if isinstance(x, str) and ',' not in x else process_entity_list(x) if isinstance(x, str) else (None, None))
    df['Similar Entities'] = results.apply(lambda x: x[0] if x else None)
    df['Entity URIs'] = results.apply(lambda x: x[1] if x else None)
    return df

df = pd.read_excel('../Entity_Relation_Extraction/EntityandRelationfromQuestion.xlsx')
# df = df.head(1) # Just demonstrating on the first row, because run the whole dataset will take a long time
# Assuming 'df' is your DataFrame with a column 'Named Entities'
df = find_most_similar_entities(df, 'Named Entities')  # Replace 'Named Entities' with the actual column name

# Save the modified DataFrame to an Excel file
df.to_excel("SimilarEntitiesWithBERT.xlsx", index=False)
df
# Out:
#                                                 Text  \
# 0  Who is working in the Computational Materials ...
#
#                         Named Entities Predicate Verbs  \
# 0  the Computational Materials Science            work
#
#                                     Similar Entities  \
# 0  [computational materials science, Computationa...
#
#                                          Entity URIs
# 0  [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...

# %% [markdown]
# Note: The similarity matching above is not always effective. For example, entity'BAM reference data: results of ASTM E139 -11 creep tests on a reference material of Nimonic 75 nickel-base alloy' should contain such an entity "BAM reference data" within the top 5 similar entity.However, the top five matched entities may not contain the correct answer.
#
#
# This suggests that we need to improve our similarity matching methods for better results. This could serve as a future work. Here, we simply include entities from the knowledge graph that are relevant to entities mentioned in the question.

# %%
import pandas as pd
import ast  # Add this import to use ast.literal_eval

# Assuming you've already loaded your DataFrames
df_entity = pd.read_excel('../Entity_Relation_Extraction/extracted_entity_list .xlsx')
df = pd.read_excel('SimilarEntitiesWithBERT.xlsx')


# Assuming df and df_entity are already loaded as you mentioned

# Function to safely convert string representations of lists to actual lists
def safe_list_eval(cell_value):
    try:
        # Attempt to evaluate the string as a list
        return ast.literal_eval(cell_value)
    except (ValueError, SyntaxError):
        # If there's an error (e.g., cell_value is not a string representation of a list), return a list with the original cell_value
        return [cell_value] if cell_value else []

# Initialize 'Similar Entities' and 'Entity URIs' columns as lists if they are not already and not empty
for i in range(len(df)):
    df.at[i, 'Similar Entities'] = safe_list_eval(df.at[i, 'Similar Entities'])
    df.at[i, 'Entity URIs'] = safe_list_eval(df.at[i, 'Entity URIs'])

# Iterate through each element in the "Named Entities" column of df
for i, named_entities in enumerate(df['Named Entities']):
    indexes = []
    # Iterate through df_entity and check each element
    for index, row in df_entity.iterrows():
        word = row['entity_label']
        if isinstance(word, str) and named_entities in word:
            indexes.append(index)
    
    if indexes:
        matched_entity_label = df_entity.at[indexes[-1], 'entity_label']
        matched_entity_uri = df_entity.at[indexes[-1], 'entity_uri']
        
        if matched_entity_label not in df.at[i, 'Similar Entities']:
            df.at[i, 'Similar Entities'].append(matched_entity_label)
            df.at[i, 'Entity URIs'].append(matched_entity_uri)

# Save the modified DataFrame to an Excel file
df.to_excel("SimilarEntitiesWithBERT+1.xlsx", index=False)
df
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6                        Molecular Dynamics
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   [Computational materials science, Computationa...
# 1   [Elemental Multiperspective Material Ontology ...
# 2   [datasets, dataset, Image data, data portal, d...
# 3   [Ebrahim Norouzi, Ebrahim Norouzi, Ahmad Zainu...
# 4   [paraview, ParaView, ParaView, data portal, da...
# 5   [Volker Hofmann, Dr.  Volker Hofmann, Tilmann ...
# 6   [molecular dynamics, Visual Molecular Dynamics...
# 7   [Molecular Dynamics (MD), Crystallography Open...
# 8   [Computational materials science, Computationa...
# 9   [Pyiron, Pyrho, pyDOE, cython, Cython, http://...
# 10  [Analytic bond-order potentials, Mechanical Be...
# 11  [Python scripts, Java, Java, python, Python, M...
# 12  [electronic lab notebook, Jupyter notebooks, E...
# 13  [molecular dynamics, Visual Molecular Dynamics...
# 14  [Computational materials science, Computationa...
# 15  [['Dusseldorf Advanced Material Simulation Kit...
# 16  [Ontologies for Materials Science, Computation...
# 17  [acronym, Silicon, SIRIUS, Crystallography Ope...
# 18  [acronym, Project, project, project, Instrumen...
# 19  [ontology, ontology alignment, ontology matchi...
# 20  [Materials Project API, HybriD³ materials data...
# 21  [specification, Silicon, acronym, software, so...
# 22  [MatDB Online, MatDB, Organic Materials Databa...
# 23  [Proprietary license, Proprietary commercial s...
# 24  [Materials Cloud, Materials Commons, Materials...
# 25  [Bundesanstalt für Materialforschung und -prüf...
# 26  [mechanics of materials, Mechanics of Material...
# 27  [Transmission electron microscopy, X-ray micro...
# 28  [Elastic Constant Demo Data, Elastic Constant ...
# 29  [hardness data, educational resource, Carolina...
# 30  [hardness data, educational resource, Carolina...
# 31  [pacemaker, Atomman, matador, Plant movement, ...
# 32  [hardness data, educational resource, Carolina...
# 33  [hardness data, educational resource, Carolina...
# 34  [De Geest, P., Droesbeke, B., Eguinoa, I., Gai...
# 35  [hardness data, educational resource, Carolina...
# 36  [Bundesanstalt für Materialforschung und -prüf...
#
#                                           Entity URIs
# 0   [http://demo.fiz-karlsruhe.de/matwerk/E49517, ...
# 1   [http://demo.fiz-karlsruhe.de/matwerk/E1126751...
# 2   [http://demo.fiz-karlsruhe.de/matwerk/E1172216...
# 3   [http://demo.fiz-karlsruhe.de/matwerk/E15879, ...
# 4   [http://demo.fiz-karlsruhe.de/matwerk/E1231097...
# 5   [http://www.wikidata.org/entity/Q84561074, htt...
# 6   [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 7   [http://demo.fiz-karlsruhe.de/matwerk/E61379, ...
# 8   [http://demo.fiz-karlsruhe.de/matwerk/E49517, ...
# 9   [http://demo.fiz-karlsruhe.de/matwerk/E457491,...
# 10  [http://demo.fiz-karlsruhe.de/matwerk/E40341, ...
# 11  [http://demo.fiz-karlsruhe.de/matwerk/E1198379...
# 12  [http://purls.helmholtz-metadaten.de/mwo/Elect...
# 13  [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 14  [http://demo.fiz-karlsruhe.de/matwerk/E49517, ...
# 15  [http://demo.fiz-karlsruhe.de/matwerk/E456536,...
# 16  [http://demo.fiz-karlsruhe.de/matwerk/E1247883...
# 17  [http://purl.obolibrary.org/obo/NCIT_C93495, h...
# 18  [http://purl.obolibrary.org/obo/NCIT_C93495, h...
# 19  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 20  [http://demo.fiz-karlsruhe.de/matwerk/E547536,...
# 21  [http://nfdi.fiz-karlsruhe.de/ontology/Specifi...
# 22  [http://demo.fiz-karlsruhe.de/matwerk/E1146342...
# 23  [http://demo.fiz-karlsruhe.de/matwerk/E748254,...
# 24  [http://demo.fiz-karlsruhe.de/matwerk/E1027029...
# 25  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...
# 26  [http://demo.fiz-karlsruhe.de/matwerk/E54629, ...
# 27  [http://demo.fiz-karlsruhe.de/matwerk/E625404,...
# 28  [http://demo.fiz-karlsruhe.de/matwerk/E1247418...
# 29  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 30  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 31  [http://demo.fiz-karlsruhe.de/matwerk/E511556,...
# 32  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 33  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 34  [http://demo.fiz-karlsruhe.de/matwerk/E964967,...
# 35  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 36  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...

# %% [markdown]
# ## Find M Most Similarest Relations and added "description"

# %% [markdown]
# ### Find Most 9 Similarest Relations with Spacy and added "description"
# Our statistical results for similarity matching show that extracting the 9 most similar relations can cover the most exemplary question. Additionally, some answers to questions are included in the descriptive information, so such "mwo:description" and "dcterms:description" will be added.
#
# Here, SpaCy's en_core_web_lg model is efficient for relation matching, compare to BERT model.

# %%
import spacy
def find_most_similar_relationships(df, relationship_column):
    # Load the spaCy English model
    nlp = spacy.load("en_core_web_lg")

    # Read data from an Excel file
    df_relationship = pd.read_excel('../Entity_Relation_Extraction/extracted_relation_list.xlsx')

    # Convert the second column to lowercase and save it in a new column 'entity_lowercase'
    df_relationship['relationship_lowercase'] = df_relationship['Predicate readable'].str.lower()

    # Define a function to remove specific words and plural 's'
    def preprocess_text(text):
        # Remove specific words
        words_to_remove = {'has', 'is', 'of', 'in'}
        tokens = text.split()
        tokens = [word for word in tokens if word not in words_to_remove]

        # Remove trailing 's' for plurals
        processed_text = ' '.join(tokens)
        if processed_text.endswith('s'):
            processed_text = processed_text[:-1]

        return processed_text

    # Apply preprocessing to 'relationship_lowercase'
    df_relationship['cleaned_relationship'] = df_relationship['relationship_lowercase'].apply(preprocess_text)

    # Function to find most similar relationships
    def process_relationship(question_relationship):
        if not isinstance(question_relationship, str):
            return None, None, None

        question_word = nlp(preprocess_text(question_relationship.lower()))

        # Initialize a dictionary to store similarity scores
        similarity_scores = {}

        # Set a similarity threshold
        threshold = 0.6

        # Iterate through each word in the dataset and calculate its similarity to word1
        for index, row in df_relationship.iterrows():
            # Skip if the word is NaN
            if pd.isna(row['cleaned_relationship']):
                continue

            word2 = nlp(row['cleaned_relationship'])
            similarity = question_word.similarity(word2)
            similarity_scores[index] = similarity

            # Only store words with similarity scores above the threshold
            if similarity >= threshold:
                similarity_scores[index] = similarity

        # Find the top 9 highest similarity scores
        top_9_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:9]

        similar_relationships = []
        relationship_uris = []
        relationship_uris_withNS = []

        for index, similarity_score in top_9_similarities:
            if 0 <= index < len(df_relationship):
                similar_relationships.append(df_relationship.at[index, 'Predicate readable'])
                relationship_uris.append(df_relationship.at[index, 'Predicate URI'])
                relationship_uris_withNS.append(df_relationship.at[index, 'Predicate with Namespace'])
        if 'mwo:description' not in relationship_uris_withNS:
          relationship_uris_withNS.append('mwo:description')
        if 'dcterms:description' not in relationship_uris_withNS:
          relationship_uris_withNS.append('dcterms:description')

        return similar_relationships, relationship_uris, relationship_uris_withNS

    # Apply to each entity in the provided column of df
    results = df[relationship_column].apply(lambda x: process_relationship(x))
    df['Similar Relations'] = results.apply(lambda x: x[0] if x else None)
    df['Relation URIs'] = results.apply(lambda x: x[1] if x else None)
    df['Relation_uris_with_Namespace'] = results.apply(lambda x: x[2] if x else None)

    return df

df = pd.read_excel("SimilarEntitiesWithBERT+1.xlsx")
# Example usage with a DataFrame 'df' and a column 'Named Relationships'
df = find_most_similar_relationships(df, 'Predicate Verbs')

# To save the modified DataFrame:
df.to_excel("phrase_similarity.xlsx", index=False) 

df
# Out:
# C:\Users\ZHAOTAI\AppData\Local\Temp\ipykernel_13988\1560921423.py:49: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = question_word.similarity(word2)
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6                        Molecular Dynamics
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   ['Computational materials science', 'Computati...
# 1   ['Elemental Multiperspective Material Ontology...
# 2   ['datasets', 'dataset', 'Image data', 'data po...
# 3   ['Ebrahim Norouzi', 'Ebrahim Norouzi', 'Ahmad ...
# 4   ['paraview', 'ParaView', 'ParaView', 'data por...
# 5   ['Volker Hofmann', 'Dr.  Volker Hofmann', 'Til...
# 6   ['molecular dynamics', 'Visual Molecular Dynam...
# 7   ['Molecular Dynamics (MD)', 'Crystallography O...
# 8   ['Computational materials science', 'Computati...
# 9   ['Pyiron', 'Pyrho', 'pyDOE', 'cython', 'Cython...
# 10  ['Analytic bond-order potentials', 'Mechanical...
# 11  ['Python scripts', 'Java', 'Java', 'python', '...
# 12  ['electronic lab notebook', 'Jupyter notebooks...
# 13  ['molecular dynamics', 'Visual Molecular Dynam...
# 14  ['Computational materials science', 'Computati...
# 15  ["['Dusseldorf Advanced Material Simulation Ki...
# 16  ['Ontologies for Materials Science', 'Computat...
# 17  ['acronym', 'Silicon', 'SIRIUS', 'Crystallogra...
# 18  ['acronym', 'Project', 'project', 'project', '...
# 19  ['ontology', 'ontology alignment', 'ontology m...
# 20  ['Materials Project API', 'HybriD³ materials d...
# 21  ['specification', 'Silicon', 'acronym', 'softw...
# 22  ['MatDB Online', 'MatDB', 'Organic Materials D...
# 23  ['Proprietary license', 'Proprietary commercia...
# 24  ['Materials Cloud', 'Materials Commons', 'Mate...
# 25  ['Bundesanstalt für Materialforschung und -prü...
# 26  ['mechanics of materials', 'Mechanics of Mater...
# 27  ['Transmission electron microscopy', 'X-ray mi...
# 28  ['Elastic Constant Demo Data', 'Elastic Consta...
# 29  ['hardness data', 'educational resource', 'Car...
# 30  ['hardness data', 'educational resource', 'Car...
# 31  ['pacemaker', 'Atomman', 'matador', 'Plant mov...
# 32  ['hardness data', 'educational resource', 'Car...
# 33  ['hardness data', 'educational resource', 'Car...
# 34  ['De Geest, P., Droesbeke, B., Eguinoa, I., Ga...
# 35  ['hardness data', 'educational resource', 'Car...
# 36  ['Bundesanstalt für Materialforschung und -prü...
#
#                                           Entity URIs  \
# 0   ['http://demo.fiz-karlsruhe.de/matwerk/E49517'...
# 1   ['http://demo.fiz-karlsruhe.de/matwerk/E112675...
# 2   ['http://demo.fiz-karlsruhe.de/matwerk/E117221...
# 3   ['http://demo.fiz-karlsruhe.de/matwerk/E15879'...
# 4   ['http://demo.fiz-karlsruhe.de/matwerk/E123109...
# 5   ['http://www.wikidata.org/entity/Q84561074', '...
# 6   ['http://demo.fiz-karlsruhe.de/matwerk/E616496...
# 7   ['http://demo.fiz-karlsruhe.de/matwerk/E61379'...
# 8   ['http://demo.fiz-karlsruhe.de/matwerk/E49517'...
# 9   ['http://demo.fiz-karlsruhe.de/matwerk/E457491...
# 10  ['http://demo.fiz-karlsruhe.de/matwerk/E40341'...
# 11  ['http://demo.fiz-karlsruhe.de/matwerk/E119837...
# 12  ['http://purls.helmholtz-metadaten.de/mwo/Elec...
# 13  ['http://demo.fiz-karlsruhe.de/matwerk/E616496...
# 14  ['http://demo.fiz-karlsruhe.de/matwerk/E49517'...
# 15  ['http://demo.fiz-karlsruhe.de/matwerk/E456536...
# 16  ['http://demo.fiz-karlsruhe.de/matwerk/E124788...
# 17  ['http://purl.obolibrary.org/obo/NCIT_C93495',...
# 18  ['http://purl.obolibrary.org/obo/NCIT_C93495',...
# 19  ['https://nfdi.fiz-karlsruhe.de/ontology/Ontol...
# 20  ['http://demo.fiz-karlsruhe.de/matwerk/E547536...
# 21  ['http://nfdi.fiz-karlsruhe.de/ontology/Specif...
# 22  ['http://demo.fiz-karlsruhe.de/matwerk/E114634...
# 23  ['http://demo.fiz-karlsruhe.de/matwerk/E748254...
# 24  ['http://demo.fiz-karlsruhe.de/matwerk/E102702...
# 25  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...
# 26  ['http://demo.fiz-karlsruhe.de/matwerk/E54629'...
# 27  ['http://demo.fiz-karlsruhe.de/matwerk/E625404...
# 28  ['http://demo.fiz-karlsruhe.de/matwerk/E124741...
# 29  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 30  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 31  ['http://demo.fiz-karlsruhe.de/matwerk/E511556...
# 32  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 33  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 34  ['http://demo.fiz-karlsruhe.de/matwerk/E964967...
# 35  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 36  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...
#
#                                     Similar Relations  \
# 0   [has work package, has expertise in, has fundi...
# 1   [has related Project, related participant proj...
# 2   [has contributor, related participant project ...
# 3   [has work package, has expertise in, has fundi...
# 4   [has email address , has postal address, has w...
# 5   [has affiliation, has curation status, has par...
# 6   [has documentation, has bibliographic citation...
# 7   [required tool, has related resource, related ...
# 8   [has some values from, has work package, has r...
# 9   [has annotated source , has bibliographic cita...
# 10  [has  description, has description, has biblio...
# 11  [uses software, has example of usage, has repo...
# 12  [has type, has object type, has media type or ...
# 13  [has software, uses software, required tool, h...
# 14  [has ontology, has bibliographic citation, has...
# 15  [has type, has object type, has media type or ...
# 16  [has repository, has website, has definition s...
# 17  [has instrument model, has first element, has ...
# 18  [has  description, has description, has biblio...
# 19  [has related resource, related participant pro...
# 20  [has url, has file Extension, has repository, ...
# 21  [has  description, has description, has biblio...
# 22  [has documentation, has bibliographic citation...
# 23  [has type, has object type, has media type or ...
# 24  [has conforms to specification, belongs to, re...
# 25  [has dataset, has definition source, has annot...
# 26  [has some values from, has related resource, a...
# 27  [has dataset, has related resource, related pa...
# 28  [has license, has license, has affiliation, ha...
# 29  [has repository, has annotated source , has de...
# 30  [has dataset, has format, has format, has docu...
# 31  [has software, has Version, uses software, has...
# 32  [has related task area, has discipline, has ma...
# 33  [has  description, has description, has biblio...
# 34  [has dataset, has definition source, has annot...
# 35  [has creator, has author, has contributor, use...
# 36  [has dataset, has repository, has bibliographi...
#
#                                         Relation URIs  \
# 0   [http://purls.helmholtz-metadaten.de/mwo/hasWo...
# 1   [http://nfdi.fiz-karlsruhe.de/ontology/related...
# 2   [http://purls.helmholtz-metadaten.de/mwo/hasCo...
# 3   [http://purls.helmholtz-metadaten.de/mwo/hasWo...
# 4   [http://purls.helmholtz-metadaten.de/mwo/email...
# 5   [http://purls.helmholtz-metadaten.de/mwo/hasAf...
# 6   [http://purls.helmholtz-metadaten.de/mwo/hasDo...
# 7   [http://purls.helmholtz-metadaten.de/mwo/requi...
# 8   [http://www.w3.org/2002/07/owl#someValuesFrom,...
# 9   [http://www.w3.org/2002/07/owl#annotatedSource...
# 10  [http://purl.org/dc/terms/description, http://...
# 11  [http://www.ebi.ac.uk/swo/SWO_0000082, http://...
# 12  [http://www.w3.org/1999/02/22-rdf-syntax-ns#ty...
# 13  [https://nfdi.fiz-karlsruhe.de/ontology/Softwa...
# 14  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 15  [http://www.w3.org/1999/02/22-rdf-syntax-ns#ty...
# 16  [http://purls.helmholtz-metadaten.de/mwo/hasRe...
# 17  [http://purls.helmholtz-metadaten.de/mwo/instr...
# 18  [http://purl.org/dc/terms/description, http://...
# 19  [http://purls.helmholtz-metadaten.de/mwo/hasRe...
# 20  [http://nfdi.fiz-karlsruhe.de/ontology/url, ht...
# 21  [http://purl.org/dc/terms/description, http://...
# 22  [http://purls.helmholtz-metadaten.de/mwo/hasDo...
# 23  [http://www.w3.org/1999/02/22-rdf-syntax-ns#ty...
# 24  [http://purls.helmholtz-metadaten.de/mwo/confo...
# 25  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 26  [http://www.w3.org/2002/07/owl#someValuesFrom,...
# 27  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 28  [http://www.ebi.ac.uk/swo/has_license, http://...
# 29  [http://purls.helmholtz-metadaten.de/mwo/hasRe...
# 30  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 31  [https://nfdi.fiz-karlsruhe.de/ontology/Softwa...
# 32  [http://purls.helmholtz-metadaten.de/mwo/relat...
# 33  [http://purl.org/dc/terms/description, http://...
# 34  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 35  [http://purls.helmholtz-metadaten.de/mwo/hasCr...
# 36  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
#
#                          Relation_uris_with_Namespace
# 0   [mwo:hasWorkPackage, mwo:hasExpertiseIn, nfdic...
# 1   [nfdicore:relatedProject, mwo:relatedParticipa...
# 2   [mwo:hasContributor, mwo:relatedParticipantPro...
# 3   [mwo:hasWorkPackage, mwo:hasExpertiseIn, nfdic...
# 4   [mwo:emailAddress, mwo:hasPostalAddress, mwo:h...
# 5   [mwo:hasAffiliation, ns2:IAO_0000114, nfdicore...
# 6   [mwo:hasDocumentation, dcterms:bibliographicCi...
# 7   [mwo:requiredTool, mwo:hasRelatedResource, mwo...
# 8   [owl:someValuesFrom, mwo:hasWorkPackage, mwo:h...
# 9   [owl:annotatedSource, dcterms:bibliographicCit...
# 10  [dcterms:description, mwo:description, dcterms...
# 11  [ns3:SWO_0000082, ns2:IAO_0000112, mwo:hasRepo...
# 12  [rdf:type, nfdicore:objectType, dc:contributor...
# 13  [nfdicore:Software, ns3:SWO_0000082, mwo:requi...
# 14  [nfdicore:Ontology, dcterms:bibliographicCitat...
# 15  [rdf:type, nfdicore:objectType, dc:contributor...
# 16  [mwo:hasRepository, mwo:hasWebsite, ns2:IAO_00...
# 17  [mwo:instrumentModel, rdf:first, mwo:hasDocume...
# 18  [dcterms:description, mwo:description, dcterms...
# 19  [mwo:hasRelatedResource, mwo:relatedParticipan...
# 20  [nfdicore:url, nfdicore:fileExtension, mwo:has...
# 21  [dcterms:description, mwo:description, dcterms...
# 22  [mwo:hasDocumentation, dcterms:bibliographicCi...
# 23  [rdf:type, nfdicore:objectType, dc:contributor...
# 24  [mwo:conformsToSpecification, mwo:belongsTo, m...
# 25  [nfdicore:Dataset, ns2:IAO_0000119, owl:annota...
# 26  [owl:someValuesFrom, mwo:hasRelatedResource, o...
# 27  [nfdicore:Dataset, mwo:hasRelatedResource, mwo...
# 28  [ns3:has_license, dcterms:license, mwo:hasAffi...
# 29  [mwo:hasRepository, owl:annotatedSource, ns2:I...
# 30  [nfdicore:Dataset, dcterms:format, mwo:hasForm...
# 31  [nfdicore:Software, mwo:hasVersion, ns3:SWO_00...
# 32  [mwo:relatedTaskArea, mwo:hasDiscipline, mwo:m...
# 33  [dcterms:description, mwo:description, dcterms...
# 34  [nfdicore:Dataset, ns2:IAO_0000119, owl:annota...
# 35  [mwo:hasCreator, mwo:hasAuthor, mwo:hasContrib...
# 36  [nfdicore:Dataset, mwo:hasRepository, dcterms:...

# %% [markdown]
# ## Sentence Similarity between Given Question and Descriptions
# We find that the interval descriptions could contain some answers to a certain question, so we do sentence similarity matching between the sentence of the given question and interval description to find the most 8 similar entities, wich contain relevant information.

# %%
# List of texts to be processed， which are questions extracted from the Competency Questions of the Materials Cloud Ontology
texts = [
    'Who is working in the Computational Materials Science field?',
    'What are the research projects associated to EMMO?',
    'Who are the contributors of the data "datasets"?',
    'Who is working with Researcher "Ebrahim Norouzi" in the same group?',
    'Who is the email address of "ParaView"?',
    'What are the affiliations of Volker Hofmann?',
    'What is "Molecular Dynamics" Software? List the programming language, documentation page, repository, and license information.',
    'What are pre- and post-processing tools for MD simulations?',
    'What are some workflow environments for computational materials science?',
    'How should I cite pyiron?',
    'Where can I find a list of interatomic potentials?',
    'What are python libraries used for calculating local atomic structural environment?',
    'What are the electronic lab notebooks available?',
    'What are the software for Molecular Dynamics (MD)?',
    'What are the ontologies in nanomaterials domain?',
    'What is DAMASK?',
    'What are the data portals for materials science ontologies?',
    'What are the instruments for APT?',
    'In which institution can I find tomography equipment?',
    'What are the educational resources for Ontology?',
    'What is the API of Materials Project?',
    'Which simulation software have a python API?',
    'What is the documentation of the "MatDB Online"?',
    'What are the types of software licenses?',
    'What are the software used to produce the data in the Materials Cloud repository?',
    'What are datasets produced by the BAM organization?',
    'What are some available datasets of mechanical properties of steels?',
    'What are datasets related to "Transmission electron microscopy"?',
    'What is the license of the dataset "Elastic Constant Demo Data"?',
    'What is the repository for "BAM reference data"?',
    'What are the different data formats in the "BAM reference data"?',
    'What is the software version of "pacemaker"?',
    'What is the field of research "BAM reference data"?',
    'What is the description of the "BAM reference data"?',
    'What are the datasets produced in 2022?',
    'Who are the creators of the "BAM reference data"?',
    'What are the datasets published by "BAM"?'
]

# %%
import pandas as pd
from transformers import BertTokenizer, BertModel
import torch
from scipy.spatial.distance import cosine

# Load your DataFrame
df_des = pd.read_excel(('../Entity_Relation_Extraction/extracted_entity_list .xlsx'))

# Function to load the model and tokenizer
def get_model_and_tokenizer(model_name="bert-base-uncased"):
    tokenizer = BertTokenizer.from_pretrained(model_name)
    model = BertModel.from_pretrained(model_name)
    return model, tokenizer

# Function to encode a sentence
def encode_sentence(sentence, model, tokenizer):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1)

# Function to compare two sentences
def compare_sentences(sentence1, sentence2, model, tokenizer):
    embedding1 = encode_sentence(sentence1, model, tokenizer)
    embedding2 = encode_sentence(sentence2, model, tokenizer)
    similarity = 1 - cosine(embedding1[0].numpy(), embedding2[0].numpy())
    return similarity

# Load the pre-trained model and tokenizer
model, tokenizer = get_model_and_tokenizer()

# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=["Text", "Similar Entities", "Entity URIs", "Similarities"])
threshold = 0.7  # Define the similarity score threshold

# Exemplary texts to compare with the entity descriptions, because run the whole dataset will take a long time
texts = [
    'What are pre- and post-processing tools for MD simulations?',
]
# For each sentence in texts
for sentence1 in texts:
    similarities = []
    # Compute similarity with each sentence in df_des
    for idx, row in df_des.iterrows():
        sentence2 = str(row["entity_description"])  # Ensure sentence2 is a string
        similarity = compare_sentences(sentence1, sentence2, model, tokenizer)
        if similarity > threshold:  # Only consider similarities above the threshold
            similarities.append((similarity, idx))
    
    # Continue only if there are similarities above the threshold
    if similarities:
        # Sort indices by similarity and select top results
        top_indices = sorted(similarities, key=lambda x: x[0], reverse=True)[:8]

        # Extract similar entities, their URIs, and similarities
        similar_entities = [df_des.iloc[idx]["entity_label"] for _, idx in top_indices]
        entity_uris = [df_des.iloc[idx]["entity_uri"] for _, idx in top_indices]
        similarity_scores = [sim[0] for sim in top_indices]

        # Add to the results DataFrame
        results_df = pd.concat([results_df, pd.DataFrame({"Text": [sentence1], 
                                                          "Similar Entities": [similar_entities], 
                                                          "Entity URIs": [entity_uris],
                                                          "Similarities": [similarity_scores]})], ignore_index=True)

# To save the modified DataFrame:
results_df.to_excel("sentence_similarity.xlsx", index=False) 

# Print out the sentences with their similarities above the threshold
for index, row in results_df.iterrows():
    print(f"Text: {row['Text']}")
    for i, (entity, uri, similarity) in enumerate(zip(row['Similar Entities'], row['Entity URIs'], row['Similarities'])):
        print(f"{i+1}. Entity: {entity}, URI: {uri}, Similarity: {similarity}")
    print("\n")
# Out:
# Text: What are pre- and post-processing tools for MD simulations?
# 1. Entity: OVITO basic, URI: http://demo.fiz-karlsruhe.de/matwerk/E461321, Similarity: 0.8328317999839783
# 2. Entity: AML, URI: http://demo.fiz-karlsruhe.de/matwerk/E473879, Similarity: 0.8171683549880981
# 3. Entity: MDTraj, URI: http://demo.fiz-karlsruhe.de/matwerk/E482672, Similarity: 0.8128784894943237
# 4. Entity: Extensible Self-optimizing Phase Equilibria Infrastructure, URI: http://demo.fiz-karlsruhe.de/matwerk/E491546, Similarity: 0.806013286113739
# 5. Entity: Pizza.py Toolkit, URI: http://demo.fiz-karlsruhe.de/matwerk/E481691, Similarity: 0.8016204237937927
# 6. Entity: Yet another force field, URI: http://demo.fiz-karlsruhe.de/matwerk/E487592, Similarity: 0.8011416792869568
# 7. Entity: Graphical Interface for Materials Simulations, URI: http://demo.fiz-karlsruhe.de/matwerk/E469997, Similarity: 0.7979493737220764
# 8. Entity: freud, URI: http://demo.fiz-karlsruhe.de/matwerk/E483654, Similarity: 0.797276496887207

# %%
df_sentence = pd.read_excel('sentence_similarity.xlsx')
df_sentence
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1    Who are the contributors of the data "datasets"?
# 2   Who is working with Researcher "Ebrahim Norouz...
# 3             Who is the email address of "ParaView"?
# 4   What is "Molecular Dynamics" Software? List th...
# 5   What are pre- and post-processing tools for MD...
# 6   What are some workflow environments for comput...
# 7   Where can I find a list of interatomic potenti...
# 8   What are python libraries used for calculating...
# 9   What are the software for Molecular Dynamics (...
# 10   What are the ontologies in nanomaterials domain?
# 11  What are the data portals for materials scienc...
# 12   What are the educational resources for Ontology?
# 13              What is the API of Materials Project?
# 14       Which simulation software have a python API?
# 15   What is the documentation of the "MatDB Online"?
# 16           What are the types of software licenses?
# 17  What are the software used to produce the data...
# 18  What are datasets produced by the BAM organiza...
# 19  What are some available datasets of mechanical...
# 20  What are datasets related to "Transmission ele...
# 21  What is the license of the dataset "Elastic Co...
# 22   What is the repository for "BAM reference data"?
# 23  What are the different data formats in the "BA...
# 24       What is the software version of "pacemaker"?
# 25  What is the field of research "BAM reference d...
# 26  What is the description of the "BAM reference ...
# 27  Who are the creators of the "BAM reference data"?
# 28          What are the datasets published by "BAM"?
#
#                                      Similar Entities  \
# 0   ['Materials Design Ontology (MDO)', 'Open Mate...
# 1   ['has creator', 'resource', 'about material', ...
# 2             ['Phonon database at Kyoto university']
# 3                                     ['dateCreated']
# 4   ['Computational Materials Repository (CMR)', '...
# 5   ['OVITO basic', 'AML', 'MDTraj', 'Extensible S...
# 6   ['Simmate', 'matminer', 'Pyiron', 'The Materia...
# 7   ['potentials repository', 'Workshop: Workflows...
# 8   ['Pyscal', 'matminer', 'icet', 'Calphy', 'py4v...
# 9   ['Yet another force field', 'dynasor', 'QuickF...
# 10  ['MaterialsMine (MM)', 'Materials Design Ontol...
# 11  ['MatPortal', 'Materials Design Ontology (MDO)...
# 12              ['glossary', 'glossary', 'MatPortal']
# 13                      ['Python Materials Genomics']
# 14  ['OpenPathSampling', 'py4vasp', 'CompositionSp...
# 15  ['NOMAD Metainfo', 'Materials Platform for Dat...
# 16                                     ['has format']
# 17  ['Materials Data Repository', 'has repository'...
# 18  ['NOMAD Metainfo', 'has creator', 'about mater...
# 19  ['Elastic Constant Demo Data', 'MatDat', 'Poly...
# 20  ['materials database', 'Atomic Simulation Reci...
# 21  ['Metadata schemes for materials science data'...
# 22  ['has repository', 'about material', 'provided...
# 23  ['File Format', 'Computational Materials Repos...
# 24  ['eLabFTW', 'Qe-tools', 'Phonon database at Ky...
# 25  ['Phonon database at Kyoto university', 'has t...
# 26  ['instrument model', 'about material', 'has fo...
# 27  ['Electronic Structure Common Data Format (ESC...
# 28  ['NOMAD Metainfo', 'about material', 'has crea...
#
#                                           Entity URIs  \
# 0   ['http://demo.fiz-karlsruhe.de/matwerk/E113125...
# 1   ['http://purls.helmholtz-metadaten.de/mwo/hasC...
# 2   ['http://demo.fiz-karlsruhe.de/matwerk/E1074846']
# 3                  ['https://schema.org/dateCreated']
# 4   ['http://demo.fiz-karlsruhe.de/matwerk/E106024...
# 5   ['http://demo.fiz-karlsruhe.de/matwerk/E461321...
# 6   ['http://demo.fiz-karlsruhe.de/matwerk/E594506...
# 7   ['http://purls.helmholtz-metadaten.de/mwo/Pote...
# 8   ['http://demo.fiz-karlsruhe.de/matwerk/E413687...
# 9   ['http://demo.fiz-karlsruhe.de/matwerk/E487592...
# 10  ['http://demo.fiz-karlsruhe.de/matwerk/E112825...
# 11  ['http://demo.fiz-karlsruhe.de/matwerk/E102989...
# 12  ['https://nfdi.fiz-karlsruhe.de/ontology/Gloss...
# 13   ['http://demo.fiz-karlsruhe.de/matwerk/E478754']
# 14  ['http://demo.fiz-karlsruhe.de/matwerk/E476801...
# 15  ['http://demo.fiz-karlsruhe.de/matwerk/E115696...
# 16  ['http://purls.helmholtz-metadaten.de/mwo/hasF...
# 17  ['http://demo.fiz-karlsruhe.de/matwerk/E104284...
# 18  ['http://demo.fiz-karlsruhe.de/matwerk/E115696...
# 19  ['http://demo.fiz-karlsruhe.de/matwerk/E124741...
# 20  ['http://purls.helmholtz-metadaten.de/mwo/Mate...
# 21  ['http://demo.fiz-karlsruhe.de/matwerk/E112375...
# 22  ['http://purls.helmholtz-metadaten.de/mwo/hasR...
# 23  ['http://purl.org/dc/terms/FileFormat', 'http:...
# 24  ['http://demo.fiz-karlsruhe.de/matwerk/E527852...
# 25  ['http://demo.fiz-karlsruhe.de/matwerk/E107484...
# 26  ['http://purls.helmholtz-metadaten.de/mwo/inst...
# 27  ['http://demo.fiz-karlsruhe.de/matwerk/E115392...
# 28  ['http://demo.fiz-karlsruhe.de/matwerk/E115696...
#
#                                          Similarities
# 0   [0.7672713398933411, 0.7573269009590149, 0.754...
# 1   [0.776042640209198, 0.7632700800895691, 0.7532...
# 2                                [0.7229445576667786]
# 3                                [0.7022454738616943]
# 4   [0.8298476338386536, 0.8252119421958923, 0.821...
# 5   [0.8328317999839783, 0.8171683549880981, 0.812...
# 6   [0.7957924008369446, 0.7936322093009949, 0.790...
# 7   [0.768103837966919, 0.7318059206008911, 0.7256...
# 8   [0.8711916208267212, 0.8447266221046448, 0.838...
# 9   [0.7991176843643188, 0.7940086126327515, 0.790...
# 10  [0.8046298623085022, 0.8037128448486328, 0.794...
# 11  [0.7930157780647278, 0.7827778458595276, 0.777...
# 12  [0.7161357402801514, 0.7161357402801514, 0.710...
# 13                               [0.7113270163536072]
# 14  [0.7834775447845459, 0.7825598120689392, 0.770...
# 15  [0.7491410374641418, 0.7417116165161133, 0.728...
# 16                               [0.7056126594543457]
# 17  [0.7893211841583252, 0.7822422385215759, 0.781...
# 18  [0.7455052733421326, 0.7418683767318726, 0.725...
# 19  [0.8365386128425598, 0.8124993443489075, 0.797...
# 20  [0.7953129410743713, 0.7883117198944092, 0.787...
# 21  [0.7731270790100098, 0.766732931137085, 0.7635...
# 22  [0.7522177696228027, 0.738351047039032, 0.7343...
# 23  [0.7954392433166504, 0.7801300883293152, 0.779...
# 24  [0.7181329727172852, 0.713926374912262, 0.7111...
# 25  [0.7492271065711975, 0.7417762875556946, 0.733...
# 26  [0.76318359375, 0.7620680928230286, 0.75693047...
# 27  [0.7332726120948792, 0.7325447201728821, 0.728...
# 28  [0.7672038674354553, 0.7433326244354248, 0.740...

# %%
df_word = pd.read_excel('phrase_similarity.xlsx')
df_sentence = pd.read_excel('sentence_similarity.xlsx')
df_sentence.drop(columns=['Similarities'], inplace=True)

# and convert them if they are not
for col in ['Similar Entities', 'Entity URIs']:
    if not isinstance(df_word[col].iloc[0], list):
        df_word[col] = df_word[col].apply(eval)
    if not isinstance(df_sentence[col].iloc[0], list):
        df_sentence[col] = df_sentence[col].apply(eval)


# Perform the merge operation ensuring all entries from df_word are retained
df_merged = pd.merge(df_sentence, df_word, on='Text', how='right', suffixes=('_sentence', '_word'))

# Combine 'Similar Entities' and 'Entity URIs' columns while removing duplicates
df_merged['Similar Entities'] = df_merged.apply(
    lambda row: list(set((row['Similar Entities_sentence'] if isinstance(row['Similar Entities_sentence'], list) else []) + 
                         (row['Similar Entities_word'] if isinstance(row['Similar Entities_word'], list) else []))),
    axis=1
)
df_merged['Entity URIs'] = df_merged.apply(
    lambda row: list(set((row['Entity URIs_sentence'] if isinstance(row['Entity URIs_sentence'], list) else []) + 
                         (row['Entity URIs_word'] if isinstance(row['Entity URIs_word'], list) else []))),
    axis=1
)

# Drop the now redundant columns
df_merged.drop(columns=['Similar Entities_sentence', 'Similar Entities_word', 
                        'Entity URIs_sentence', 'Entity URIs_word'], inplace=True)

# Let's check the merged dataframe
df_merged.to_excel('relevant_entities_relations.xlsx', index=False)

df_merged
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6                        Molecular Dynamics
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                     Similar Relations  \
# 0   ['has work package', 'has expertise in', 'has ...
# 1   ['has related Project', 'related participant p...
# 2   ['has contributor', 'related participant proje...
# 3   ['has work package', 'has expertise in', 'has ...
# 4   ['has email address ', 'has postal address', '...
# 5   ['has affiliation', 'has curation status', 'ha...
# 6   ['has documentation', 'has bibliographic citat...
# 7   ['required tool', 'has related resource', 'rel...
# 8   ['has some values from', 'has work package', '...
# 9   ['has annotated source ', 'has bibliographic c...
# 10  ['has  description', 'has description', 'has b...
# 11  ['uses software', 'has example of usage', 'has...
# 12  ['has type', 'has object type', 'has media typ...
# 13  ['has software', 'uses software', 'required to...
# 14  ['has ontology', 'has bibliographic citation',...
# 15  ['has type', 'has object type', 'has media typ...
# 16  ['has repository', 'has website', 'has definit...
# 17  ['has instrument model', 'has first element', ...
# 18  ['has  description', 'has description', 'has b...
# 19  ['has related resource', 'related participant ...
# 20  ['has url', 'has file Extension', 'has reposit...
# 21  ['has  description', 'has description', 'has b...
# 22  ['has documentation', 'has bibliographic citat...
# 23  ['has type', 'has object type', 'has media typ...
# 24  ['has conforms to specification', 'belongs to'...
# 25  ['has dataset', 'has definition source', 'has ...
# 26  ['has some values from', 'has related resource...
# 27  ['has dataset', 'has related resource', 'relat...
# 28  ['has license', 'has license', 'has affiliatio...
# 29  ['has repository', 'has annotated source ', 'h...
# 30  ['has dataset', 'has format', 'has format', 'h...
# 31  ['has software', 'has Version', 'uses software...
# 32  ['has related task area', 'has discipline', 'h...
# 33  ['has  description', 'has description', 'has b...
# 34  ['has dataset', 'has definition source', 'has ...
# 35  ['has creator', 'has author', 'has contributor...
# 36  ['has dataset', 'has repository', 'has bibliog...
#
#                                         Relation URIs  \
# 0   ['http://purls.helmholtz-metadaten.de/mwo/hasW...
# 1   ['http://nfdi.fiz-karlsruhe.de/ontology/relate...
# 2   ['http://purls.helmholtz-metadaten.de/mwo/hasC...
# 3   ['http://purls.helmholtz-metadaten.de/mwo/hasW...
# 4   ['http://purls.helmholtz-metadaten.de/mwo/emai...
# 5   ['http://purls.helmholtz-metadaten.de/mwo/hasA...
# 6   ['http://purls.helmholtz-metadaten.de/mwo/hasD...
# 7   ['http://purls.helmholtz-metadaten.de/mwo/requ...
# 8   ['http://www.w3.org/2002/07/owl#someValuesFrom...
# 9   ['http://www.w3.org/2002/07/owl#annotatedSourc...
# 10  ['http://purl.org/dc/terms/description', 'http...
# 11  ['http://www.ebi.ac.uk/swo/SWO_0000082', 'http...
# 12  ['http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 13  ['https://nfdi.fiz-karlsruhe.de/ontology/Softw...
# 14  ['https://nfdi.fiz-karlsruhe.de/ontology/Ontol...
# 15  ['http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 16  ['http://purls.helmholtz-metadaten.de/mwo/hasR...
# 17  ['http://purls.helmholtz-metadaten.de/mwo/inst...
# 18  ['http://purl.org/dc/terms/description', 'http...
# 19  ['http://purls.helmholtz-metadaten.de/mwo/hasR...
# 20  ['http://nfdi.fiz-karlsruhe.de/ontology/url', ...
# 21  ['http://purl.org/dc/terms/description', 'http...
# 22  ['http://purls.helmholtz-metadaten.de/mwo/hasD...
# 23  ['http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 24  ['http://purls.helmholtz-metadaten.de/mwo/conf...
# 25  ['https://nfdi.fiz-karlsruhe.de/ontology/Datas...
# 26  ['http://www.w3.org/2002/07/owl#someValuesFrom...
# 27  ['https://nfdi.fiz-karlsruhe.de/ontology/Datas...
# 28  ['http://www.ebi.ac.uk/swo/has_license', 'http...
# 29  ['http://purls.helmholtz-metadaten.de/mwo/hasR...
# 30  ['https://nfdi.fiz-karlsruhe.de/ontology/Datas...
# 31  ['https://nfdi.fiz-karlsruhe.de/ontology/Softw...
# 32  ['http://purls.helmholtz-metadaten.de/mwo/rela...
# 33  ['http://purl.org/dc/terms/description', 'http...
# 34  ['https://nfdi.fiz-karlsruhe.de/ontology/Datas...
# 35  ['http://purls.helmholtz-metadaten.de/mwo/hasC...
# 36  ['https://nfdi.fiz-karlsruhe.de/ontology/Datas...
#
#                          Relation_uris_with_Namespace  \
# 0   ['mwo:hasWorkPackage', 'mwo:hasExpertiseIn', '...
# 1   ['nfdicore:relatedProject', 'mwo:relatedPartic...
# 2   ['mwo:hasContributor', 'mwo:relatedParticipant...
# 3   ['mwo:hasWorkPackage', 'mwo:hasExpertiseIn', '...
# 4   ['mwo:emailAddress', 'mwo:hasPostalAddress', '...
# 5   ['mwo:hasAffiliation', 'ns2:IAO_0000114', 'nfd...
# 6   ['mwo:hasDocumentation', 'dcterms:bibliographi...
# 7   ['mwo:requiredTool', 'mwo:hasRelatedResource',...
# 8   ['owl:someValuesFrom', 'mwo:hasWorkPackage', '...
# 9   ['owl:annotatedSource', 'dcterms:bibliographic...
# 10  ['dcterms:description', 'mwo:description', 'dc...
# 11  ['ns3:SWO_0000082', 'ns2:IAO_0000112', 'mwo:ha...
# 12  ['rdf:type', 'nfdicore:objectType', 'dc:contri...
# 13  ['nfdicore:Software', 'ns3:SWO_0000082', 'mwo:...
# 14  ['nfdicore:Ontology', 'dcterms:bibliographicCi...
# 15  ['rdf:type', 'nfdicore:objectType', 'dc:contri...
# 16  ['mwo:hasRepository', 'mwo:hasWebsite', 'ns2:I...
# 17  ['mwo:instrumentModel', 'rdf:first', 'mwo:hasD...
# 18  ['dcterms:description', 'mwo:description', 'dc...
# 19  ['mwo:hasRelatedResource', 'mwo:relatedPartici...
# 20  ['nfdicore:url', 'nfdicore:fileExtension', 'mw...
# 21  ['dcterms:description', 'mwo:description', 'dc...
# 22  ['mwo:hasDocumentation', 'dcterms:bibliographi...
# 23  ['rdf:type', 'nfdicore:objectType', 'dc:contri...
# 24  ['mwo:conformsToSpecification', 'mwo:belongsTo...
# 25  ['nfdicore:Dataset', 'ns2:IAO_0000119', 'owl:a...
# 26  ['owl:someValuesFrom', 'mwo:hasRelatedResource...
# 27  ['nfdicore:Dataset', 'mwo:hasRelatedResource',...
# 28  ['ns3:has_license', 'dcterms:license', 'mwo:ha...
# 29  ['mwo:hasRepository', 'owl:annotatedSource', '...
# 30  ['nfdicore:Dataset', 'dcterms:format', 'mwo:ha...
# 31  ['nfdicore:Software', 'mwo:hasVersion', 'ns3:S...
# 32  ['mwo:relatedTaskArea', 'mwo:hasDiscipline', '...
# 33  ['dcterms:description', 'mwo:description', 'dc...
# 34  ['nfdicore:Dataset', 'ns2:IAO_0000119', 'owl:a...
# 35  ['mwo:hasCreator', 'mwo:hasAuthor', 'mwo:hasCo...
# 36  ['nfdicore:Dataset', 'mwo:hasRepository', 'dct...
#
#                                      Similar Entities  \
# 0   [Computational Materials Science, Computationa...
# 1   [R. S. Elliott and E. B. Tadmor, "Knowledgebas...
# 2   [Framework for curation and distribution of re...
# 3   [Ebrahim Norouzi, Ahmad Zainul Ihsan, Hosni Id...
# 4          [data portal, ParaView, paraview, dataset]
# 5   [Volker Hofmann, Dr. Tilmann Hickel, Tilmann H...
# 6   [Computational Chemistry, Visual Molecular Dyn...
# 7   [Brunswick, AML, Crystallography Open Database...
# 8   [Computational Materials Science, Computationa...
# 9   [Pyrho, Pyiron, pyDOE, cython, Cython, http://...
# 10  [Mechanical Behavior of Interface-Dominated Ma...
# 11  [Java, measurement processing, Materials Commo...
# 12  [Jupyter notebooks, electronic lab notebook, E...
# 13  [Brunswick, Quantum Chemistry, molecular dynam...
# 14  [Computational Materials Science, Nanocrystall...
# 15  [['Dusseldorf Advanced Material Simulation Kit...
# 16  [Computational Material Sample Ontology, Ontol...
# 17  [acronym, Instrument, APT analysis using Compo...
# 18  [project, acronym, Instrument, X-ray imaging, ...
# 19  [ontology alignment, The MatWerk ontology, ont...
# 20  [Materials Platform for Data Science, Material...
# 21  [specification, acronym, software, R. S. Ellio...
# 22  [MatDB, Organic Materials Database (OMDB), is ...
# 23  [software repository, Proprietary license, doc...
# 24  [Materials Cloud, controlled vocabulary, Mater...
# 25  [Brunswick, acronym, Bundesanstalt für Materia...
# 26  [Thermodynamics and kinetics of metallic alloy...
# 27  [X-ray microscopy, Confocal microscopy, X-ray ...
# 28  [NeXus Data Format, semantic resource, Elastic...
# 29  [BAM reference data: results of ASTM E139 -11 ...
# 30  [BAM reference data: results of ASTM E139 -11 ...
# 31  [https://pacemaker.readthedocs.io/en/latest/, ...
# 32  [BAM reference data: results of ASTM E139 -11 ...
# 33  [BAM reference data: results of ASTM E139 -11 ...
# 34  [J. Magnus Rahm and Paul Erhart WulffPack: A P...
# 35  [BAM reference data: results of ASTM E139 -11 ...
# 36  [Brunswick, acronym, Bundesanstalt für Materia...
#
#                                           Entity URIs
# 0   [http://demo.fiz-karlsruhe.de/matwerk/E42042, ...
# 1   [http://demo.fiz-karlsruhe.de/matwerk/E1152404...
# 2   [http://demo.fiz-karlsruhe.de/matwerk/E1248382...
# 3   [http://demo.fiz-karlsruhe.de/matwerk/E1245566...
# 4   [http://demo.fiz-karlsruhe.de/matwerk/E419156,...
# 5   [http://demo.fiz-karlsruhe.de/matwerk/E20504, ...
# 6   [http://demo.fiz-karlsruhe.de/matwerk/E70752, ...
# 7   [http://demo.fiz-karlsruhe.de/matwerk/E481691,...
# 8   [http://demo.fiz-karlsruhe.de/matwerk/E42042, ...
# 9   [http://demo.fiz-karlsruhe.de/matwerk/E405551,...
# 10  [http://demo.fiz-karlsruhe.de/matwerk/E40341, ...
# 11  [http://demo.fiz-karlsruhe.de/matwerk/E833696,...
# 12  [http://demo.fiz-karlsruhe.de/matwerk/E1199927...
# 13  [http://demo.fiz-karlsruhe.de/matwerk/E70752, ...
# 14  [http://demo.fiz-karlsruhe.de/matwerk/E43779, ...
# 15  [http://demo.fiz-karlsruhe.de/matwerk/E858396,...
# 16  [http://demo.fiz-karlsruhe.de/matwerk/E1247323...
# 17  [http://demo.fiz-karlsruhe.de/matwerk/E1247879...
# 18  [http://nfdi.fiz-karlsruhe.de/ontology/Project...
# 19  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 20  [http://demo.fiz-karlsruhe.de/matwerk/E547536,...
# 21  [http://demo.fiz-karlsruhe.de/matwerk/E1247879...
# 22  [http://demo.fiz-karlsruhe.de/matwerk/E1146342...
# 23  [http://demo.fiz-karlsruhe.de/matwerk/E770421,...
# 24  [http://demo.fiz-karlsruhe.de/matwerk/E547536,...
# 25  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...
# 26  [http://demo.fiz-karlsruhe.de/matwerk/E47972, ...
# 27  [http://demo.fiz-karlsruhe.de/matwerk/E625404,...
# 28  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 29  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 30  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 31  [http://demo.fiz-karlsruhe.de/matwerk/E531966,...
# 32  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 33  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 34  [http://demo.fiz-karlsruhe.de/matwerk/E941507,...
# 35  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 36  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...
